# %% [markdown]
# # Stacked GRU regression

# %%
# Suppress warnings 
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="darkgrid")

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
import tensorflow as tf
tf.random.set_seed(0)
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import GRU, Dense, Activation
from tensorflow.keras.utils import plot_model
from tensorflow.keras import optimizers, backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
TRAIN_RANGE = (datetime(1949, 1, 1), datetime(1956, 12, 1))
VALID_RANGE = (datetime(1957, 1, 1), datetime(1958, 12, 1))
TEST_RANGE = (datetime(1959, 1, 1), datetime(1960, 12, 1))
TIMESTEPS = 12  # Input 12 months to predict next month

# %% [markdown]
# ## 1. Read in dataset

# %%
data = pd.read_csv('data/airline-passengers.csv')
data.index = pd.to_datetime(data.Month)  # Set datetime index
data.drop(['Month'], axis=1, inplace=True)

# %%
data.plot(figsize=(14, 8), title='Monthly airline passengers')

# %% [markdown]
# ## 2.1 Normalize dataset

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data['NormalizedPassengers'] = scaler.fit_transform(data['Passengers'].values.reshape(-1, 1)).flatten()
data[['NormalizedPassengers']].plot(figsize=(14, 8), title='Monthly normalized airline passengers')

# %% [markdown]
# ## 2.2 Preprocess dataset

# %%
def create_dataset(data, timesteps=TIMESTEPS):
    """Create input and output pairs for training lstm.
    Params:
        data (pandas.DataFrame): Normalized dataset
        timesteps (int, default: TIMESTEPS): Input time length 
    Returns:
        X (numpy.array): Input for lstm
        y (numpy.array): Output for lstm
        y_date (list): Datetime of output
        start_values (list): Start valeus of each input
    """
    X, y, y_date, start_values = [], [], [], []
    
    for i in range(len(data) - timesteps):
        Xt = data.iloc[i:i+timesteps].values
        yt = data.iloc[i+timesteps]
        yt_date = data.index[i+timesteps].to_pydatetime()
        
        # Subtract a start value from each values in the timestep.
        start_value = Xt[0]
        Xt = Xt - start_value
        yt = yt - start_value
        
        X.append(Xt)
        y.append(yt)
        y_date.append(yt_date)
        start_values.append(start_value)
        
    return np.array(X), np.array(y), y_date, start_values

# %%
def split_train_valid_test(X, y, y_date, train_range=TRAIN_RANGE, valid_range=VALID_RANGE, test_range=TEST_RANGE):
    """Split X and y into train, valid, and test periods.
    Params:
        X (numpy.array): Input for lstm
        y (numpy.array): Output for lstm
        y_date (list): Datetime of output
        train_range (tuple): Train period
        valid_range (tuple): Validation period
        test_range (tuple): Test period
    Returns:
        X_train (pandas.DataFrame)
        X_valid (pandas.DataFrame)
        X_test (pandas.DataFrame)
        y_train (pandas.DataFrame)
        y_valid (pandas.DataFrame)
        y_test (pandas.DataFrame)
        y_date_train (list)
        y_date_valid (list)
        y_date_test (list)
    """
    train_end_idx = y_date.index(train_range[1])
    valid_end_idx = y_date.index(valid_range[1])
    
    X_train = X[:train_end_idx+1, :]
    X_valid = X[train_end_idx+1:valid_end_idx+1, :]
    X_test = X[valid_end_idx+1:, :]
    
    y_train = y[:train_end_idx+1]
    y_valid = y[train_end_idx+1:valid_end_idx+1]
    y_test = y[valid_end_idx+1:]
    
    y_date_train = y_date[:train_end_idx+1]
    y_date_valid = y_date[train_end_idx+1:valid_end_idx+1]
    y_date_test = y_date[valid_end_idx+1:]
    
    return X_train, X_valid, X_test, y_train, y_valid, y_test, y_date_train, y_date_valid, y_date_test

# %%
# Create input and output pairs for training lstm.
X, y, y_date, start_values = create_dataset(data[['NormalizedPassengers']])

# Split X and y into train, valid, and test periods.
X_train, X_valid, X_test, y_train, y_valid, y_test, y_date_train, y_date_valid, y_date_test = split_train_valid_test(X, y, y_date)

# %%
print(X_train.shape, X_valid.shape, X_test.shape)
print(y_train.shape, y_valid.shape, y_test.shape)
# Out:
# (84, 12, 1) (24, 12, 1) (24, 12, 1)
# (84, 1) (24, 1) (24, 1)

# %% [markdown]
# ## 3. Create stacked GRU regression model

# %%
def create_model(timesteps=TIMESTEPS):
    model = Sequential()
    model.add(GRU(128, return_sequences=True, input_shape=(timesteps, 1), name='gru_1'))  # Input timesteps months with scalar value.
    model.add(GRU(32, name='gru_2'))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer=optimizers.Adam(lr=0.01), metrics=['mean_absolute_error'])
    return model

# %%
# Create model
model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_1 (GRU)                  (None, 12, 128)           50304
# _________________________________________________________________
# gru_2 (GRU)                  (None, 32)                15552
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 65,889
# Trainable params: 65,889
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Callbacks of training.
es = EarlyStopping(monitor='val_mean_absolute_error', min_delta=0, patience=15, verbose=1, mode='auto')
fn = 'trained_model.h5'
mc = ModelCheckpoint(filepath=fn, save_best_only=True)
callbacks = [es, mc]

# %%
# Start training model.
fit = model.fit(
    X_train, y_train, 
    batch_size=32,
    epochs=1000, 
    verbose=2,
    validation_data=(X_valid, y_valid), 
    callbacks=callbacks)
# Out:
# Train on 84 samples, validate on 24 samples
# Epoch 1/1000
# 84/84 - 3s - loss: 0.0585 - mean_absolute_error: 0.1847 - val_loss: 0.0328 - val_mean_absolute_error: 0.1703
# Epoch 2/1000
# 84/84 - 0s - loss: 0.0153 - mean_absolute_error: 0.1047 - val_loss: 0.0081 - val_mean_absolute_error: 0.0824
# Epoch 3/1000
# 84/84 - 0s - loss: 0.0072 - mean_absolute_error: 0.0786 - val_loss: 0.0018 - val_mean_absolute_error: 0.0353
# Epoch 4/1000
# 84/84 - 0s - loss: 0.0017 - mean_absolute_error: 0.0339 - val_loss: 0.0042 - val_mean_absolute_error: 0.0545
# Epoch 5/1000
# 84/84 - 0s - loss: 0.0036 - mean_absolute_error: 0.0524 - val_loss: 0.0014 - val_mean_absolute_error: 0.0309
# Epoch 6/1000
# 84/84 - 0s - loss: 9.4228e-04 - mean_absolute_error: 0.0248 - val_loss: 0.0027 - val_mean_absolute_error: 0.0433
# Epoch 7/1000
# 84/84 - 0s - loss: 0.0023 - mean_absolute_error: 0.0396 - val_loss: 0.0022 - val_mean_absolute_error: 0.0388
# Epoch 8/1000
# 84/84 - 0s - loss: 0.0013 - mean_absolute_error: 0.0292 - val_loss: 0.0012 - val_mean_absolute_error: 0.0290
# Epoch 9/1000
# 84/84 - 0s - loss: 0.0011 - mean_absolute_error: 0.0266 - val_loss: 0.0015 - val_mean_absolute_error: 0.0328
# Epoch 10/1000
# 84/84 - 0s - loss: 0.0014 - mean_absolute_error: 0.0305 - val_loss: 0.0011 - val_mean_absolute_error: 0.0289
# Epoch 11/1000
# 84/84 - 0s - loss: 0.0010 - mean_absolute_error: 0.0257 - val_loss: 0.0015 - val_mean_absolute_error: 0.0313
# Epoch 12/1000
# 84/84 - 0s - loss: 0.0011 - mean_absolute_error: 0.0271 - val_loss: 0.0012 - val_mean_absolute_error: 0.0280
# Epoch 13/1000
# 84/84 - 0s - loss: 8.6795e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0011 - val_mean_absolute_error: 0.0276
# Epoch 14/1000
# 84/84 - 0s - loss: 9.0636e-04 - mean_absolute_error: 0.0239 - val_loss: 0.0011 - val_mean_absolute_error: 0.0280
# Epoch 15/1000
# 84/84 - 0s - loss: 8.9875e-04 - mean_absolute_error: 0.0238 - val_loss: 0.0010 - val_mean_absolute_error: 0.0269
# Epoch 16/1000
# 84/84 - 0s - loss: 8.3093e-04 - mean_absolute_error: 0.0229 - val_loss: 0.0011 - val_mean_absolute_error: 0.0267
# Epoch 17/1000
# 84/84 - 0s - loss: 8.3669e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0011 - val_mean_absolute_error: 0.0266
# Epoch 18/1000
# 84/84 - 0s - loss: 8.2828e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0011 - val_mean_absolute_error: 0.0261
# Epoch 19/1000
# 84/84 - 0s - loss: 7.9303e-04 - mean_absolute_error: 0.0225 - val_loss: 0.0010 - val_mean_absolute_error: 0.0258
# Epoch 20/1000
# 84/84 - 0s - loss: 7.9004e-04 - mean_absolute_error: 0.0223 - val_loss: 0.0010 - val_mean_absolute_error: 0.0257
# Epoch 21/1000
# 84/84 - 0s - loss: 7.8779e-04 - mean_absolute_error: 0.0222 - val_loss: 0.0010 - val_mean_absolute_error: 0.0253
# Epoch 22/1000
# 84/84 - 0s - loss: 7.6717e-04 - mean_absolute_error: 0.0222 - val_loss: 0.0011 - val_mean_absolute_error: 0.0253
# Epoch 23/1000
# 84/84 - 0s - loss: 7.7551e-04 - mean_absolute_error: 0.0227 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
# Epoch 24/1000
# 84/84 - 0s - loss: 7.6297e-04 - mean_absolute_error: 0.0224 - val_loss: 0.0010 - val_mean_absolute_error: 0.0245
# Epoch 25/1000
# 84/84 - 0s - loss: 7.4945e-04 - mean_absolute_error: 0.0220 - val_loss: 0.0010 - val_mean_absolute_error: 0.0244
# Epoch 26/1000
# 84/84 - 0s - loss: 7.4148e-04 - mean_absolute_error: 0.0219 - val_loss: 0.0010 - val_mean_absolute_error: 0.0240
# Epoch 27/1000
# 84/84 - 0s - loss: 7.3225e-04 - mean_absolute_error: 0.0219 - val_loss: 0.0010 - val_mean_absolute_error: 0.0239
# Epoch 28/1000
# 84/84 - 0s - loss: 7.3565e-04 - mean_absolute_error: 0.0220 - val_loss: 0.0010 - val_mean_absolute_error: 0.0237
# Epoch 29/1000
# 84/84 - 0s - loss: 7.2240e-04 - mean_absolute_error: 0.0218 - val_loss: 0.0010 - val_mean_absolute_error: 0.0236
# Epoch 30/1000
# 84/84 - 0s - loss: 7.2003e-04 - mean_absolute_error: 0.0217 - val_loss: 9.9278e-04 - val_mean_absolute_error: 0.0235
# Epoch 31/1000
# 84/84 - 0s - loss: 7.1354e-04 - mean_absolute_error: 0.0216 - val_loss: 0.0010 - val_mean_absolute_error: 0.0233
# Epoch 32/1000
# 84/84 - 0s - loss: 7.0869e-04 - mean_absolute_error: 0.0215 - val_loss: 0.0010 - val_mean_absolute_error: 0.0232
# Epoch 33/1000
# 84/84 - 0s - loss: 7.1420e-04 - mean_absolute_error: 0.0217 - val_loss: 0.0011 - val_mean_absolute_error: 0.0234
# Epoch 34/1000
# 84/84 - 0s - loss: 7.0647e-04 - mean_absolute_error: 0.0216 - val_loss: 0.0010 - val_mean_absolute_error: 0.0230
# Epoch 35/1000
# 84/84 - 0s - loss: 7.1039e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0010 - val_mean_absolute_error: 0.0229
# Epoch 36/1000
# 84/84 - 0s - loss: 7.0905e-04 - mean_absolute_error: 0.0213 - val_loss: 0.0011 - val_mean_absolute_error: 0.0230
# Epoch 37/1000
# 84/84 - 0s - loss: 6.9819e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0011 - val_mean_absolute_error: 0.0231
# Epoch 38/1000
# 84/84 - 0s - loss: 6.9673e-04 - mean_absolute_error: 0.0213 - val_loss: 0.0011 - val_mean_absolute_error: 0.0227
# Epoch 39/1000
# 84/84 - 0s - loss: 6.9790e-04 - mean_absolute_error: 0.0212 - val_loss: 0.0011 - val_mean_absolute_error: 0.0227
# Epoch 40/1000
# 84/84 - 0s - loss: 7.0155e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0011 - val_mean_absolute_error: 0.0230
# Epoch 41/1000
# 84/84 - 0s - loss: 6.9624e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0011 - val_mean_absolute_error: 0.0228
# Epoch 42/1000
# 84/84 - 0s - loss: 7.1793e-04 - mean_absolute_error: 0.0213 - val_loss: 0.0011 - val_mean_absolute_error: 0.0227
# Epoch 43/1000
# 84/84 - 0s - loss: 6.9328e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0011 - val_mean_absolute_error: 0.0232
# Epoch 44/1000
# 84/84 - 0s - loss: 7.1153e-04 - mean_absolute_error: 0.0216 - val_loss: 0.0011 - val_mean_absolute_error: 0.0234
# Epoch 45/1000
# 84/84 - 0s - loss: 6.8837e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0010 - val_mean_absolute_error: 0.0225
# Epoch 46/1000
# 84/84 - 0s - loss: 7.1820e-04 - mean_absolute_error: 0.0212 - val_loss: 0.0010 - val_mean_absolute_error: 0.0225
# Epoch 47/1000
# 84/84 - 0s - loss: 6.8416e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0011 - val_mean_absolute_error: 0.0234
# Epoch 48/1000
# 84/84 - 0s - loss: 7.0348e-04 - mean_absolute_error: 0.0213 - val_loss: 0.0011 - val_mean_absolute_error: 0.0233
# Epoch 49/1000
# 84/84 - 0s - loss: 6.9630e-04 - mean_absolute_error: 0.0212 - val_loss: 0.0010 - val_mean_absolute_error: 0.0226
# Epoch 50/1000
# 84/84 - 0s - loss: 7.1007e-04 - mean_absolute_error: 0.0213 - val_loss: 0.0010 - val_mean_absolute_error: 0.0226
# Epoch 51/1000
# 84/84 - 0s - loss: 7.0194e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0011 - val_mean_absolute_error: 0.0227
# Epoch 52/1000
# 84/84 - 0s - loss: 6.8765e-04 - mean_absolute_error: 0.0210 - val_loss: 0.0011 - val_mean_absolute_error: 0.0229
# Epoch 53/1000
# 84/84 - 0s - loss: 6.8881e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0010 - val_mean_absolute_error: 0.0225
# Epoch 54/1000
# 84/84 - 0s - loss: 6.7993e-04 - mean_absolute_error: 0.0207 - val_loss: 0.0011 - val_mean_absolute_error: 0.0227
# Epoch 55/1000
# 84/84 - 0s - loss: 6.7647e-04 - mean_absolute_error: 0.0206 - val_loss: 0.0011 - val_mean_absolute_error: 0.0231
# Epoch 56/1000
# 84/84 - 0s - loss: 7.0082e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0011 - val_mean_absolute_error: 0.0228
# Epoch 57/1000
# 84/84 - 0s - loss: 6.7159e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0011 - val_mean_absolute_error: 0.0233
# Epoch 58/1000
# 84/84 - 0s - loss: 6.8459e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0011 - val_mean_absolute_error: 0.0231
# Epoch 59/1000
# 84/84 - 0s - loss: 6.6798e-04 - mean_absolute_error: 0.0204 - val_loss: 0.0011 - val_mean_absolute_error: 0.0227
# Epoch 60/1000
# 84/84 - 0s - loss: 7.1351e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0010 - val_mean_absolute_error: 0.0226
# Epoch 00060: early stopping

# %%
# Plot training history
fig, (axL, axR) = plt.subplots(ncols=2, figsize=(10, 4))
axL.plot(fit.history['loss'], label="loss (mse) for training")
axL.plot(fit.history['val_loss'], label="loss (mse) for validation")
axL.set_title('model loss')
axL.set_xlabel('epoch')
axL.set_ylabel('loss')
axL.legend(loc='upper right')

axR.plot(fit.history['mean_absolute_error'], label="mae for training")
axR.plot(fit.history['val_mean_absolute_error'], label="mae for validation")
axR.set_title('model mse')
axR.set_xlabel('epoch')
axR.set_ylabel('mse')
axR.legend(loc='upper right')

plt.show()

# Load best model
model = load_model(fn)

# %%
def evaluate_model(data, scaler, X_train, X_valid, X_test, y_train, y_valid, y_test, y_date_train, y_date_valid, y_date_test, start_values, model):
    """Evaluate trained model by rmse (root mean squared error) and mae (mean absolute error)'"""
    
    # Predict next month passengers
    pred_train = model.predict(X_train)
    pred_valid = model.predict(X_valid)
    pred_test = model.predict(X_test)
    
    # Add start_values that were subtracted when preprocessing.
    pred_train  = pred_train + start_values[:len(X_train)]
    pred_valid  = pred_valid + start_values[len(X_train):len(X_train)+len(X_valid)]
    pred_test  = pred_test + start_values[len(X_train)+len(X_valid):]
    
    # Inverse transform normalization
    pred_train = scaler.inverse_transform(pred_train).flatten()
    pred_valid = scaler.inverse_transform(pred_valid).flatten()
    pred_test = scaler.inverse_transform(pred_test).flatten()
    
    pred_df = data.copy()
    pred_df.loc[y_date_train[0]:y_date_train[-1], 'PredictionTrain'] = pred_train
    pred_df.loc[y_date_valid[0]:y_date_valid[-1], 'PredictionValid'] = pred_valid
    pred_df.loc[y_date_test[0]:y_date_test[-1], 'PredictionTest'] = pred_test
    pred_df[['Passengers', 'PredictionTrain', 'PredictionValid', 'PredictionTest']].plot(figsize=(12, 6), title='Predicted monthly airline passengers')
    fig.show()
    
    # Add start_values that were subtracted when preprocessing.
    y_train  = y_train + start_values[:len(X_train)]
    y_valid  = y_valid + start_values[len(X_train):len(X_train)+len(X_valid)]
    y_test  = y_test + start_values[len(X_train)+len(X_valid):]
    
    # Inverse transform normalization
    y_train = scaler.inverse_transform(y_train).flatten()
    y_valid = scaler.inverse_transform(y_valid).flatten()
    y_test = scaler.inverse_transform(y_test).flatten()
    
    # Evaluate prediction scores of model.
    for y, pred, mode in zip([y_train, y_valid, y_test], [pred_train, pred_valid, pred_test], ['train', 'valid', 'test']):
        rmse = np.sqrt(mean_squared_error(y, pred))
        mae = mean_absolute_error(y, pred)
        print(f'{mode} rmse: {rmse:.06f}, mae: {mae:.06f}')

# %%
evaluate_model(data, scaler, X_train, X_valid, X_test, y_train, y_valid, y_test, y_date_train, y_date_valid, y_date_test, start_values, model)
# Out:
# train rmse: 13.855842, mae: 11.187705
# valid rmse: 16.321391, mae: 12.162357
# test rmse: 22.465969, mae: 18.159484
